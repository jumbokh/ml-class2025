# %%
from keras.models import Model
from keras.layers import Dense, Input
from keras.datasets import mnist
import numpy as np

# Hyper parameters
batch_size = 128
nb_epoch = 100

# Parameters for MNIST dataset
img_rows, img_cols = 28, 28

# Parameters for denoising autoencoder
nb_visible = img_rows * img_cols
nb_hidden = 500
corruption_level = 0.3

# %%
# Load MNIST Dataset
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
# Add random noise
x_train_noisy = x_train + corruption_level * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + corruption_level * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
print(x_train_noisy.shape)
print(x_test_noisy.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
# Build autoencoder model
input_img = Input(shape=(nb_visible,))
encoded = Dense(nb_hidden, activation='relu')(input_img)
decoded = Dense(nb_visible, activation='sigmoid')(encoded)

autoencoder = Model(inputs=input_img, outputs=decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 500)            │       392,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 784)            │       392,784 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 785,284 (3.00 MB)
#  Trainable params: 785,284 (3.00 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train
autoencoder.fit(x_train_noisy, x_train,
                epochs=nb_epoch, batch_size=batch_size, shuffle=True, verbose=1,
                validation_data=(x_test_noisy, x_test))
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.7091 - val_loss: 0.7059
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.7047 - val_loss: 0.7016
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.7004 - val_loss: 0.6975
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6964 - val_loss: 0.6934
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6924 - val_loss: 0.6895
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6885 - val_loss: 0.6856
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6847 - val_loss: 0.6818
# Epoch 8/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6809 - val_loss: 0.6780
# Epoch 9/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6771 - val_loss: 0.6741
# Epoch 10/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6733 - val_loss: 0.6702
# Epoch 11/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6694 - val_loss: 0.6662
# Epoch 12/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6654 - val_loss: 0.6620
# Epoch 13/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6613 - val_loss: 0.6578
# Epoch 14/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6570 - val_loss: 0.6534
# Epoch 15/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6527 - val_loss: 0.6489
# Epoch 16/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6481 - val_loss: 0.6441
# Epoch 17/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6434 - val_loss: 0.6392
# Epoch 18/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6385 - val_loss: 0.6340
# Epoch 19/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6332 - val_loss: 0.6287
# Epoch 20/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6279 - val_loss: 0.6231
# Epoch 21/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6223 - val_loss: 0.6172
# Epoch 22/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6164 - val_loss: 0.6111
# Epoch 23/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6103 - val_loss: 0.6048
# Epoch 24/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6039 - val_loss: 0.5982
# Epoch 25/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.5973 - val_loss: 0.5913
# Epoch 26/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.5904 - val_loss: 0.5842
# Epoch 27/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.5833 - val_loss: 0.5769
# Epoch 28/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.5760 - val_loss: 0.5693
# Epoch 29/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.5685 - val_loss: 0.5615
# Epoch 30/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.5606 - val_loss: 0.5535
# Epoch 31/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.5525 - val_loss: 0.5453
# Epoch 32/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.5445 - val_loss: 0.5370
# Epoch 33/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.5362 - val_loss: 0.5286
# Epoch 34/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.5279 - val_loss: 0.5200
# Epoch 35/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.5191 - val_loss: 0.5114
# Epoch 36/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.5107 - val_loss: 0.5028
# Epoch 37/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5021 - val_loss: 0.4942
# Epoch 38/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4935 - val_loss: 0.4856
# Epoch 39/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4848 - val_loss: 0.4770
# Epoch 40/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4765 - val_loss: 0.4686
# Epoch 41/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4681 - val_loss: 0.4603
# Epoch 42/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4599 - val_loss: 0.4521
# Epoch 43/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4518 - val_loss: 0.4441
# Epoch 44/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4436 - val_loss: 0.4363
# Epoch 45/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.4360 - val_loss: 0.4287
# Epoch 46/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.4286 - val_loss: 0.4214
# Epoch 47/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.4213 - val_loss: 0.4143
# Epoch 48/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.4142 - val_loss: 0.4075
# Epoch 49/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.4075 - val_loss: 0.4009
# Epoch 50/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.4008 - val_loss: 0.3946
# Epoch 51/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3949 - val_loss: 0.3886
# Epoch 52/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3889 - val_loss: 0.3829
# Epoch 53/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3830 - val_loss: 0.3774
# Epoch 54/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3777 - val_loss: 0.3722
# Epoch 55/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3724 - val_loss: 0.3673
# Epoch 56/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3676 - val_loss: 0.3626
# Epoch 57/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3632 - val_loss: 0.3582
# Epoch 58/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3586 - val_loss: 0.3540
# Epoch 59/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3545 - val_loss: 0.3501
# Epoch 60/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3504 - val_loss: 0.3463
# Epoch 61/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3469 - val_loss: 0.3428
# Epoch 62/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3434 - val_loss: 0.3395
# Epoch 63/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3404 - val_loss: 0.3363
# Epoch 64/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3369 - val_loss: 0.3334
# Epoch 65/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3340 - val_loss: 0.3306
# Epoch 66/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3313 - val_loss: 0.3279
# Epoch 67/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3287 - val_loss: 0.3255
# Epoch 68/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3263 - val_loss: 0.3231
# Epoch 69/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3238 - val_loss: 0.3209
# Epoch 70/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3217 - val_loss: 0.3188
# Epoch 71/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3195 - val_loss: 0.3168
# Epoch 72/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3176 - val_loss: 0.3150
# Epoch 73/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3156 - val_loss: 0.3132
# Epoch 74/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3139 - val_loss: 0.3115
# Epoch 75/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3124 - val_loss: 0.3100
# Epoch 76/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3108 - val_loss: 0.3085
# Epoch 77/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3094 - val_loss: 0.3071
# Epoch 78/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3079 - val_loss: 0.3057
# Epoch 79/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3062 - val_loss: 0.3044
# Epoch 80/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3053 - val_loss: 0.3032
# Epoch 81/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3039 - val_loss: 0.3021
# Epoch 82/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3024 - val_loss: 0.3010
# Epoch 83/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3017 - val_loss: 0.3000
# Epoch 84/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3009 - val_loss: 0.2990
# Epoch 85/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2995 - val_loss: 0.2980
# Epoch 86/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2989 - val_loss: 0.2971
# Epoch 87/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2979 - val_loss: 0.2963
# Epoch 88/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2969 - val_loss: 0.2955
# Epoch 89/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2963 - val_loss: 0.2947
# Epoch 90/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2952 - val_loss: 0.2939
# Epoch 91/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2947 - val_loss: 0.2932
# Epoch 92/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2937 - val_loss: 0.2925
# Epoch 93/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2931 - val_loss: 0.2919
# Epoch 94/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2925 - val_loss: 0.2913
# Epoch 95/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2915 - val_loss: 0.2907
# Epoch 96/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2914 - val_loss: 0.2901
# Epoch 97/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2908 - val_loss: 0.2895
# Epoch 98/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2901 - val_loss: 0.2890
# Epoch 99/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2897 - val_loss: 0.2885
# Epoch 100/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2891 - val_loss: 0.2880

# %%
# Evaluate
evaluation = autoencoder.evaluate(x_test_noisy, x_test, batch_size=batch_size, verbose=1)
print('\nSummary: Loss over the test dataset: %.2f' % (evaluation))
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2851
#
# Summary: Loss over the test dataset: 0.29

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Decode test images 
decoded_imgs = autoencoder.predict(x_test_noisy)

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step
